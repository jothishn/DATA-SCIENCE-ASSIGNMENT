# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7"

# %%
r=requests.get(url)
htmlcontent = r.content

# %%
print(htmlcontent)
# Out:
# b'\n\n<!DOCTYPE HTML>\n<html xml:lang="en-IN" lang="en-IN">\n\n<head>\n<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n<meta http-equiv="Content-Type" content="text/html;charset=UTF-8">\n<meta name="referrer" content="no-referrer-when-downgrade">\n<meta name="viewport" content="width=device-width, initial-scale=1.0"> \n\n<title>Xiaomi India | Mobile | TV | Fitness | Smart Home | Lifestyle -   Mi India</title>\n\n      <meta name="description" content="Xiaomi India official store helps you to discover Mi and Redmi Mobiles, accessories and ecosystem products including \xe2\x9c\x93Mi11 \xe2\x9c\x93Redmi Note 10 Pro Max \xe2\x9c\x93Mi Smart Band 6 \xe2\x9c\x93Redmi Air Purifier and many more">\n  \n    <link rel="canonical" href="https://www.mi.com/in/" />\n<link rel="alternate" media="only screen and (max-width: 640px)" href="https://mobile.mi.com/in/"/>\n<link rel="alternate" href="https://www.mi.com/hk/" hreflang="zh-HK" />\n<link rel="alternate" href="https://www.mi.com/tw/" h
# ...

# %%
soup = BeautifulSoup(htmlcontent,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE HTML>
#
# <html lang="en-IN" xml:lang="en-IN">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Xiaomi India | Mobile | TV | Fitness | Smart Home | Lifestyle -   Mi India</title>
# <meta content="Xiaomi India official store helps you to discover Mi and Redmi Mobiles, accessories and ecosystem products including ✓Mi11 ✓Redmi Note 10 Pro Max ✓Mi Smart Band 6 ✓Redmi Air Purifier and many more" name="description"/>
# <link href="https://www.mi.com/in/" rel="canonical"/>
# <link href="https://mobile.mi.com/in/" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="https://www.mi.com/hk/" hreflang="zh-HK" rel="alternate"/>
# <link href="https://www.mi.com/tw/" hreflang="zh-TW" rel="alternate"/>
# ...

# %%
# Commonly used types of objects:
# print(type(title)) # 1. tag
# print(type(title.string)) # 2. NavigableString
# print(type(soup)) # 3. BeautifulSoup

# %%
#Get the title of the HTML page
title = soup.title
print(title)
# Out:
# <title>Xiaomi India | Mobile | TV | Fitness | Smart Home | Lifestyle -   Mi India</title>

# %%
paras = soup.find_all('p')
print(paras)
# Out:
# [<p class="descp"></p>, <p class="price follow">
# <span class="dollar"></span> </p>, <p class="descp"></p>, <p class="price follow">
# <span class="dollar"></span> </p>, <p class="descp"></p>, <p class="price follow">
# <span class="dollar"></span> </p>, <p class="descp"></p>, <p class="price follow">
# <span class="dollar"></span> </p>, <p class="descp"></p>, <p class="price follow">
# <span class="dollar"></span> </p>, <p class="descp"></p>, <p class="price follow">
# <span class="dollar"></span> </p>, <p class="descp"></p>, <p class="price follow">
# <span class="dollar"></span> </p>, <p class="descp"></p>, <p class="price follow">
# ...

# %%
#Get first element in the HTMl Page
print(soup.find('p'))
# Out:
# <p class="descp"></p>

# %%
#Get classes of any element in the HTML page
print(soup.find('p')['class'])
# Out:
# ['descp']

# %%
# Find all the elements with class lead
print(soup.find_all("p", class_="lead"))
# Out:
# []

# %%
# Get the text from the tags/soup
print(soup.find('p').get_text())

# %%
print(soup.get_text())
# Out:
# Xiaomi India | Mobile | TV | Fitness | Smart Home | Lifestyle -   Mi India
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Xiaomi India
# Get Mi Store App
# Online Help
#
#
#
# Retail Store
#
#
# Mi Home
#
# Mi Stores
#
# Mi Authorized Stores
#
#
#
#
#
#
#
# Cart ( 0 )
#
#
#
#
# Your cart is empty!
#
#
#
#
#
# Subtotal ()
# ₹
#
# Checkout
#
#
#
#
#
#
#
#
#
#
# Sign in
#
#
# Sign up
#
#
#
#
#
#
#
#
#
# My account
#
#
# Reward Mi
#
#
# Mi VIP Club
#
#
# My reviews
#
#
# Sign Out
#
#
#
#
# Messages
# My Orders
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Xiaomi Phones
#
#
#
#
#
#
#
# Xiaomi 12 Pro 5G
# ₹54,999
#
#
#
#
#
# Xiaomi 11T Pro 5G
# From ₹34,999
#
#
#
#
#
# Xiaomi 11i Hypercharge 5G
# From ₹24,999
#
#
#
#
#
# Xiaomi 11i 5G
# From ₹24,999
#
#
#
#
#
# Xiaomi 11 Lite NE 5G
# From ₹26,999
#
#
#
#
#
# View More
#
#
#
#
#
#
#
# Redmi Phones
#
#
#
#
#
#
#
# Redmi K50i 5G
# From ₹23,999
#
#
#
#
#
# ...

# %%
# Get all the anchor tags from the page
anchors = soup.find_all('a')
all_links = set()
#Get all the links on the page:
for link in anchors:
    if(link.get('href') != '#'):
        linktext = "https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7" + str(link.get('href'))
        all_links.add(link)
        print(linktext)
# Out:
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://www.mi.com/in/
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://in.event.mi.com/in/install-mi-store
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://www.mi.com/in/service/help/#category_id=1&pagenum=1&channel=1
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://www.mi.com/in/service/authorized_stores/
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://www.mi.com/in/service/mihome/
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://www.mi.com/in/service/mi_stores/
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://www.mi.com/in/service/authorized_stores/
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://store.mi.com/in/cart
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://store.mi.com/in/cart
# https://www.mi.com/in/?tid=102aaa595660ad5847f34d54f720d7https://store.mi.com/in/site/login
# ...

# %%
container = soup.find_all("min-height",class_="breadcrumb")#It available in div tag

# %%
container
# Out:
# []

# %%
prod_name=[]
for i in range(0,len(container)):
    cust_name.append(container[i].get_text())

# %%
prod_name
# Out:
# []
