# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import Holt 
from statsmodels.tsa.holtwinters import ExponentialSmoothing 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading data

# %%
airlines_data=pd.read_excel("C:\\Users\\JOTHISH N\\Desktop\\DS\\FORECASTING\\Airlines+Data.xlsx")

# %%
airlines_data
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306
#
# [96 rows x 2 columns]

# %% [markdown]
# ### Plotting the data

# %%
airlines_data.Passengers.plot()
# Out:
# <AxesSubplot:>

# %%
len(airlines_data)
# Out:
# 96

# %% [markdown]
# ### Splitting train and test data:

# %%
train=airlines_data.head(80)
test=airlines_data.tail(16)

# %%
train
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 75 2001-04-01         269
# 76 2001-05-01         270
# 77 2001-06-01         315
# 78 2001-07-01         364
# 79 2001-08-01         347
#
# [80 rows x 2 columns]

# %%
test
# Out:
#         Month  Passengers
# 80 2001-09-01         312
# 81 2001-10-01         274
# 82 2001-11-01         237
# 83 2001-12-01         278
# 84 2002-01-01         284
# 85 2002-02-01         277
# 86 2002-03-01         317
# 87 2002-04-01         313
# 88 2002-05-01         318
# 89 2002-06-01         374
# 90 2002-07-01         413
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306

# %% [markdown]
# ### Plotting moving averages:

# %%
a=range(3,15,3)
plt.figure(figsize=(24,7))
airlines_data.Passengers.plot(label="org")
for i in a:
    airlines_data["Passengers"].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best')

# %% [markdown]
# ### Time series decomposition plot:

# %%
decompose_ts_add = seasonal_decompose(airlines_data.Passengers,period=12)
decompose_ts_add.plot()
plt.show()

# %% [markdown]
# ### ACF and PACF plots:

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(airlines_data.Passengers,lags=12)
tsa_plots.plot_pacf(airlines_data.Passengers,lags=12)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
def MAPE(pred,org):
    temp = np.abs((pred-org)/org)*100
    return np.mean(temp)

# %%
weights = np.array([0.1, 0.2, 0.3, 0.4])

# %% [markdown]
# ### Weighted moving average:

# %%
df=pd.DataFrame()
df['Passengers']=airlines_data.Passengers
df['WMA'] = df['Passengers'].rolling(4).apply(lambda x: np.sum(weights*x))
df
# Out:
#     Passengers    WMA
# 0          112    NaN
# 1          118    NaN
# 2          132    NaN
# 3          129  126.0
# 4          121  125.3
# ..         ...    ...
# 91         405  392.5
# 92         355  383.5
# 93         306  351.2
# 94         271  311.7
# 95         306  300.4
#
# [96 rows x 2 columns]

# %% [markdown]
# ### Plotting weighted moving average

# %%
df.Passengers.plot(kind='line')
df.WMA.plot(kind='line')
plt.legend()

# %% [markdown]
# ### Simple exponential smoothing:

# %%
ses_model = SimpleExpSmoothing(train["Passengers"]).fit(smoothing_level=0.2)
pred_ses = ses_model.predict(start = test.index[0],end = test.index[-1])
MAPE(pred_ses,test.Passengers)
# Out:
# 11.375850554268276

# %% [markdown]
# ### Plotting for predictions for test data:

# %%
plt.plot(pred_ses)
plt.plot(test.Passengers)

# %% [markdown]
# ### Predictions for the whole data:

# %%
plt.plot(ses_model.predict(start=airlines_data.index[0],end=airlines_data.index[-1]))
plt.plot(airlines_data.Passengers)

# %% [markdown]
# ### Running a loop to find the best smoothing level value:

# %%
acc_ses={}
for i in range(101):
    ses_model = SimpleExpSmoothing(train["Passengers"]).fit(smoothing_level=i/100)
    pred_ses = ses_model.predict(start = test.index[0],end = test.index[-1])
    acc_ses[MAPE(pred_ses,test.Passengers)]=i

print('{}:{}'.format(acc_ses[min(acc_ses.keys())],min(acc_ses.keys())))
# Out:
# 24:11.016377148078142

# %% [markdown]
# ### Building a model with 0.24 as the smoothing level value:

# %%
ses_model = SimpleExpSmoothing(train["Passengers"]).fit(smoothing_level=0.24)
pred_ses = ses_model.predict(start = test.index[0],end = test.index[-1])
MAPE(pred_ses,test.Passengers)
# Out:
# 11.016377148078142

# %% [markdown]
# ### Plotting the predictions on test data:

# %%
plt.plot(pred_ses)
plt.plot(test.Passengers)

# %% [markdown]
# ### Plotting the predictions of the whole data:

# %%
plt.plot(ses_model.predict(start=airlines_data.index[0],end=airlines_data.index[-1]))
plt.plot(airlines_data.Passengers)

# %% [markdown]
# ### Building a model with holt method:

# %%
holt_model = Holt(train["Passengers"]).fit(smoothing_level=0.8, smoothing_slope=0.3)
pred_holt = holt_model.predict(start = test.index[0],end = test.index[-1])
MAPE(pred_holt,test.Passengers)
# Out:
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\3446898267.py:1: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=0.8, smoothing_slope=0.3)
# 59.933366922606936

# %% [markdown]
# ### Plotting the predictions on test data:

# %%
plt.plot(pred_holt)
plt.plot(test.Passengers)

# %% [markdown]
# ### Plotting the predictions of the whole data:

# %%
plt.plot(holt_model.predict(start=airlines_data.index[0],end=airlines_data.index[-1]))
plt.plot(airlines_data.Passengers)

# %% [markdown]
# ### running a loop to find the best hyper parameters:

# %%
accuracy={}
for i in range(0,101):
    for j in range(0,101):
        holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
        pred_holt = holt_model.predict(start = test.index[0],end = test.index[-1])
        accuracy[MAPE(pred_holt,test.Passengers)]=(i,j)
# Out:
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
# ...
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2605435413.py:4: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=i/100, smoothing_slope=j/100)

# %%
accuracy[min(accuracy.keys())]
# Out:
# (2, 63)

# %%
min(accuracy.keys())
# Out:
# 10.257527277458138

# %% [markdown]
# ### Building a model with smoothing level=0.02 and smoothing slope=0.63:

# %%
holt_model = Holt(train["Passengers"]).fit(smoothing_level=0.02, smoothing_slope=0.63)
pred_holt = holt_model.predict(start = test.index[0],end = test.index[-1])
MAPE(pred_holt,test.Passengers)
# Out:
# C:\Users\JOTHISH N\AppData\Local\Temp\ipykernel_6568\2634338194.py:1: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   holt_model = Holt(train["Passengers"]).fit(smoothing_level=0.02, smoothing_slope=0.63)
# 10.257527277458138

# %% [markdown]
# ### Plotting the predictions on test data:

# %%
plt.plot(pred_holt)
plt.plot(test.Passengers)

# %% [markdown]
# ### Plotting the predictions of the whole data

# %%
plt.plot(holt_model.predict(start=airlines_data.index[0],end=airlines_data.index[-1]))
plt.plot(airlines_data.Passengers)

# %% [markdown]
# ### Building a model using holt winters method:

# %%
# from the moving averages plotted earlier,it can be seen that the best seasonal periods value is 12:

# %%
hw_add_add = ExponentialSmoothing(train["Passengers"],seasonal='add', trend='add',seasonal_periods=12).fit()
pred_hw_add = hw_add_add.predict(start = test.index[0],end = test.index[-1])
MAPE(pred_hw_add,test.Passengers)
# Out:
# 7.946927362397262

# %% [markdown]
# ### Plotting the predictions on the test data:

# %%
plt.plot(pred_hw_add)
plt.plot(test.Passengers)

# %% [markdown]
# ### Plotting the predictions on whole data

# %%
plt.plot(hw_add_add.predict(start=airlines_data.index[0],end=airlines_data.index[-1]))
plt.plot(airlines_data.Passengers)

# %% [markdown]
# ### Running a loop to find the best hyperparameters:

# %%
params=['add','mul']
acc_hw={}
for i in params:
    for j in params:
        hw = ExponentialSmoothing(train["Passengers"],seasonal=i, trend=j,seasonal_periods=12).fit()
        pred_hw = hw.predict(start = test.index[0],end = test.index[-1])
        acc_hw[MAPE(pred_hw,test.Passengers)]=(i,j)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
acc_hw[min(acc_hw.keys())]
# Out:
# ('mul', 'mul')

# %%
min(acc_hw.keys())
# Out:
# 1.8506873557356214

# %% [markdown]
# ### Building a model with both seasonal and trend to be multiplicative:

# %%
hw = ExponentialSmoothing(train["Passengers"],seasonal='mul', trend='mul',seasonal_periods=12).fit()
pred_hw = hw.predict(start = test.index[0],end = test.index[-1])
MAPE(pred_hw,test.Passengers)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# 1.8506873557356214

# %% [markdown]
# ### Plotting the predictions on the test data:

# %%
plt.plot(pred_hw)
plt.plot(test.Passengers)

# %% [markdown]
# ### Plotting the predictions on whole data:

# %%
plt.plot(hw.predict(start=airlines_data.index[0],end=airlines_data.index[-1]))
plt.plot(airlines_data.Passengers)

# %% [markdown]
# # Conclusions:
#
# Simplle Exponential smoothing:
#
# Best smoothing level value was found to be 0.24. Model built with this value has an rms error value of 11.01.
#
# Holt's model:
#
# Best smoothing level value was found to be 0.02 and smoothing_slope value to be 0.63. Model built with these parameters have an rms error value of 10.25
#
# Holt-Winters method:
#
# Putting both seasonal and trend to be multiplicative gives best results. The model built with these parameters give an rms error of 1.85
#
# #So Holt winters model is taken as the final model:

# %%
model_final=hw
